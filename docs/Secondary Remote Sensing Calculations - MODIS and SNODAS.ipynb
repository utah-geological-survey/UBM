# %%
# %matplotlib inline
import pandas as pd
import zipfile
import shutil
import urllib2
from urllib2 import urlopen
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as tick
import scipy.stats as sp
import statsmodels.api as sm
from pandas.stats.api import ols
from datetime import datetime
from bs4 import BeautifulSoup
from pylab import rcParams
import platform
rcParams['figure.figsize'] = 15, 10
import re
import os
import sys
import glob
import urllib
import HTMLParser
from cStringIO import StringIO

import pyproj
from pyproj import Proj

import gzip

import ftplib
import calendar
import datetime
from datetime import date

import pymodis
# Out:
# WxPython missing, no GUI enabled

# %%
'''
Locate ArcPy and add it to the path
Created on 13 Feb 2015
@author: Jamesramm
https://github.com/JamesRamm/archook/blob/master/archook.py
'''
import _winreg
import sys
from os import path
def locate_arcgis():
  '''
  Find the path to the ArcGIS Desktop installation.
  Keys to check:
  HLKM/SOFTWARE/ESRI/ArcGIS 'RealVersion' - will give the version, then we can use
  that to go to
  HKLM/SOFTWARE/ESRI/DesktopXX.X 'InstallDir'. Where XX.X is the version
  We may need to check HKLM/SOFTWARE/Wow6432Node/ESRI instead
  '''
  try:
    key = _winreg.OpenKey(_winreg.HKEY_LOCAL_MACHINE,
                          'SOFTWARE\\Wow6432Node\\ESRI\\ArcGIS', 0)

    version = _winreg.QueryValueEx(key, "RealVersion")[0][:4]

    key_string = "SOFTWARE\\Wow6432Node\\ESRI\\Desktop{0}".format(version)
    desktop_key = _winreg.OpenKey(_winreg.HKEY_LOCAL_MACHINE,
                                  key_string, 0)

    install_dir = _winreg.QueryValueEx(desktop_key, "InstallDir")[0]
    return install_dir
  except WindowsError:
    raise ImportError("Could not locate the ArcGIS directory on this machine")

def get_arcpy():  
  '''
  Allows arcpy to imported on 'unmanaged' python installations (i.e. python installations
  arcgis is not aware of).
  Gets the location of arcpy and related libs and adds it to sys.path
  '''
  install_dir = locate_arcgis()  
  arcpy = path.join(install_dir, "arcpy")
  # Check we have the arcpy directory.
  if not path.exists(arcpy):
    raise ImportError("Could not find arcpy directory in {0}".format(install_dir))

  # First check if we have a bin64 directory - this exists when arcgis is 64bit
  bin_dir = path.join(install_dir, "bin64")
  if not path.exists(bin_dir):
    # Fall back to regular 'bin' dir otherwise.
    bin_dir = path.join(install_dir, "bin")

  scripts = path.join(install_dir, "ArcToolbox", "Scripts")  
  sys.path.extend([arcpy, bin_dir, scripts])

get_arcpy()
import arcpy
arcpy.CheckOutExtension("spatial")
from arcpy import env 
from arcpy.sa import *

# %%
print("Operating System " + platform.system() + " " + platform.release())
print("Python Version " + str(sys.version))
print("Pandas Version " + str(pd.__version__))
print("Numpy Version " + str(np.__version__))
# Out:
# Operating System Windows 7
# Python Version 2.7.10 (default, May 23 2015, 09:40:32) [MSC v.1500 32 bit (Intel)]
# Pandas Version 0.19.1
# Numpy Version 1.11.2

# %%
def replace_hdr_file(hdrfile):
    """
    Replace the .hdr file for a .bil raster with the correct data for Arc processing
    Required: hdrfile -- filepath for .hdr file to replace/create
    Output:   None
    """
    # hdr file replacment string
    HDRFILE_STRING = "byteorder M\n\
    layout bil\n\
    nbands 1\n\
    nbits 16\n\
    ncols 6935\n\
    nrows 3351\n\
    ulxmap -124.729583333331703\n\
    ulymap 52.871249516804028\n\
    xdim 0.00833333333\n\
    ydim 0.00833333333\n"
    with open(hdrfile, 'w') as o:
        o.write(HDRFILE_STRING)

# %%
path= "H:/GIS/MODIS2/MODIS.gdb/"
arcpy.env.workspace = path

for rast in arcpy.ListRasters()[:3]:
        dsc = arcpy.Describe(rast)
        print(dsc.baseName)
# Out:
# PET200006c
# PET200007c
# PET200008c

# %%
for hdrfile in glob.glob("H:/GIS/SNODAS/SNODASUNZIPPED/SNODASUNGZ/*.Hdr"):
    replace_hdr_file(hdrfile)

# %%
sr = arcpy.SpatialReference(4326) #Spatial Projection WGS84

# Set output coordinate system
outCS = arcpy.SpatialReference('NAD 1983 UTM Zone 12N')  #NAD83 Zone 12 Code is 26912

# Set local variables
inMaskData = "H:/GIS/SNODAS/SNODAS.gdb/UT_HUC_area"

# from Table 4 of http://nsidc.org/data/docs/noaa/g02158_snodas_snow_cover_model/
prodcodelong = {1025: 'Precipitation', 1034: 'Snow water equivalent', 1036: 'Snow depth', 
            1038: 'Snow pack average temperature', 1039: 'Blowing snow sublimation',
            1044: 'Snow melt', 1050: 'Snow pack sublimation'}
prodcode = {1025: 'PREC', 1034: 'SWEQ', 1036: 'SNOD', 1038: 'SPAT', 1039: 'BSSB', 1044: 'SNML', 1050: 'SPSB'}

# iterate through data files creating rasters and defining projections
for dtfile in glob.glob("H:/GIS/SNODAS/SNODASUNZIPPED/SNODASUNGZ/*.dat"):
    indata = arcpy.Raster(dtfile)
    arcpy.DefineProjection_management(indata, sr)
    typAbb = prodcode[int(os.path.basename(dtfile)[8:12])]
    
    #indata.save("H:/GIS/SNODAS/SNODAS.gdb/" + typAbb + dtfile[-20:-11]) #YYYYMMDD
    
    # Execute ExtractByMask to clip snodas data to Utah watersheds
    outExtractByMask = arcpy.sa.ExtractByMask(indata, inMaskData)

    # Determine the new output feature class path and name = productcode + YYYYMMDD and save to a geodatabase
    outrast = "H:/GIS/SNODAS/SNODAS.gdb/" + typAbb + dtfile[-20:-11] #os.path.join(outWorkspace, rast)
    
    # Print name to veryfy save
    print(typAbb + dtfile[-20:-11])
    
    # Project Raster to UTM Zone 12
    arcpy.ProjectRaster_management(outExtractByMask, outrast, outCS, 'BILINEAR', '1000',\
                                   'WGS_1984_(ITRF00)_To_NAD_1983', '#', '#')

# %% [markdown]
# From http://nsidc.org/data/docs/noaa/g02158_snodas_snow_cover_model/, the file abbreviations are as follows:
# <ul type="disc">
# <li>`RAIN` = `Wet Precip`</li>
# <li>`SWEQ` = `Snow Water Equivalent`</li>
# <li>`SNOD` = `Snow Depth`</li>
# <li>`SPAT` = `Snow Pack Average Temp`</li>
# <li>`BSSB` = `Blowing Snow Sublimation`</li>
# <li>`SNML` = `Snowmelt`</li>
# <li>`SPSB` = `Snow Pack Sublimation`</li>
# </ul>

# %%
prodcode = {'us_ssmv11038wS__A':'SPAT', 'us_ssmv11044bS__T':'SNML', 'us_ssmv11050lL00T':'SPSB', 
            'us_ssmv11034tS__T':'SWEQ', 'us_ssmv01025SlL00':'RAIN', 'us_ssmv01025SlL01':'SNOW',
            'us_ssmv11036tS__T':'SNOD', 'us_ssmv11039lL00T':'BSSB'}

path = "H:/GIS/SNODAS/geotifSNODAS/SNDS/"
for filename in os.listdir(path):
    if filename.startswith("us_ssmv"):
        code = prodcode[filename[0:17]]
        yrsrt = filename.find('TNATS') + 5
        yr = filename[yrsrt:yrsrt+4]
        mo = filename[yrsrt+4:yrsrt+6]
        dy = filename[yrsrt+6:yrsrt+8]
        os.rename(os.path.join(path, filename), os.path.join(path,code+yr+mo+dy+filename[-4:]))

# %%
def mergeRasts(path, data_type = 'AET', monthRange = [1,4], yearRange = [2000,2001]):
    arcpy.env.workspace = path
    print(arcpy.ListRasters())
    
    for y in range(yearRange[0],yearRange[-1]+1): #set years converted here
        for m in range(monthRange[0],monthRange[-1]+1): #set months converted here   
            nm = data_type + str(y) + str(m).zfill(2)
            rlist=[]
            for rast in arcpy.ListRasters(nm+'*'): 
                rlist.append(rast)
            print(rlist)

# %%
path="H:/GIS/MODIS2/MODIS.gdb"
mergeRasts(path)
# Out:
# []
# [u'AET2000018', u'AET2000019']
# [u'AET2000028', u'AET2000029']
# [u'AET2000038', u'AET2000039']
# [u'AET2000048', u'AET2000049']
# [u'AET2001018', u'AET2001019']
# [u'AET2001028', u'AET2001029']
# [u'AET2001038', u'AET2001039']
# [u'AET2001048', u'AET2001049']

# %%
path = "H:/GIS/SNODAS/geotifSNODAS/SNDS/"
g = {}
from arcpy.sa import *
arcpy.env.workspace = path
arcpy.env.overwriteOutput = True

code = 'PREC'

for y in range(2003,2016):
    for m in range(1,13):
        g[code+str(y)+str(m).zfill(2)] = []
        for name in sorted(glob.glob(path+code+'*.tif')):
            rast = os.path.basename(name)
            if rast[0:4] == code and int(rast[4:8]) == y and int(rast[8:10]) == m:
                g[code+str(y)+str(m).zfill(2)].append(rast)
            else:
                pass
        if len(g[code+str(y)+str(m).zfill(2)])>0:
            print(g[code+str(y)+str(m).zfill(2)])
            calc = CellStatistics(g[code+str(y)+str(m).zfill(2)], statistics_type = "SUM", ignore_nodata="DATA")
            calc.save("H:/GIS/SNODAS/SNODAS.gdb/"+rast[0:4]+str(y).zfill(2)+str(m).zfill(2)+"SUM")
# Out:
# ['PREC20040101.tif', 'PREC20040102.tif', 'PREC20040103.tif', 'PREC20040104.tif', 'PREC20040105.tif', 'PREC20040106.tif', 'PREC20040107.tif', 'PREC20040108.tif', 'PREC20040109.tif', 'PREC20040110.tif', 'PREC20040111.tif', 'PREC20040112.tif', 'PREC20040113.tif', 'PREC20040114.tif', 'PREC20040115.tif', 'PREC20040116.tif', 'PREC20040117.tif', 'PREC20040118.tif', 'PREC20040119.tif', 'PREC20040120.tif', 'PREC20040121.tif', 'PREC20040122.tif', 'PREC20040123.tif', 'PREC20040124.tif', 'PREC20040125.tif', 'PREC20040126.tif', 'PREC20040127.tif', 'PREC20040128.tif', 'PREC20040129.tif', 'PREC20040130.tif', 'PREC20040131.tif']
# ['PREC20060801.tif', 'PREC20060802.tif', 'PREC20060803.tif', 'PREC20060804.tif', 'PREC20060805.tif', 'PREC20060806.tif', 'PREC20060807.tif', 'PREC20060808.tif', 'PREC20060809.tif', 'PREC20060810.tif', 'PREC20060811.tif', 'PREC20060812.tif', 'PREC20060813.tif', 'PREC20060814.tif', 'PREC20060815.tif', 'PREC20060816.tif', 'PREC20060817.tif', 'PREC20060818.tif', 'PREC20060819.tif', 'PREC20060820.tif', 'PREC20060821.tif', 'PREC20060822.tif', 'PREC20060823.tif', 'PREC20060824.tif', 'PREC20060825.tif', 'PREC20060828.tif', 'PREC20060829.tif', 'PREC20060830.tif', 'PREC20060831.tif']
# ['PREC20060901.tif', 'PREC20060902.tif', 'PREC20060903.tif', 'PREC20060904.tif', 'PREC20060905.tif', 'PREC20060906.tif', 'PREC20060907.tif', 'PREC20060909.tif', 'PREC20060910.tif', 'PREC20060911.tif', 'PREC20060912.tif', 'PREC20060913.tif', 'PREC20060914.tif', 'PREC20060915.tif', 'PREC20060916.tif', 'PREC20060917.tif', 'PREC20060918.tif', 'PREC20060919.tif', 'PREC20060920.tif', 'PREC20060921.tif', 'PREC20060922.tif', 'PREC20060923.tif', 'PREC20060924.tif', 'PREC20060925.tif', 'PREC20060926.tif', 'PREC20060927.tif', 'PREC20060928.tif', 'PREC20060929.tif', 'PREC20060930.tif']
# ['PREC20061002.tif', 'PREC20061003.tif', 'PREC20061004.tif', 'PREC20061005.tif', 'PREC20061006.tif', 'PREC20061007.tif', 'PREC20061008.tif', 'PREC20061009.tif', 'PREC20061010.tif', 'PREC20061011.tif', 'PREC20061012.tif', 'PREC20061013.tif', 'PREC20061014.tif', 'PREC20061015.tif', 'PREC20061016.tif', 'PREC20061017.tif', 'PREC20061018.tif', 'PREC20061019.tif', 'PREC20061020.tif', 'PREC20061021.tif', 'PREC20061022.tif', 'PREC20061023.tif', 'PREC20061024.tif', 'PREC20061025.tif', 'PREC20061026.tif', 'PREC20061027.tif', 'PREC20061028.tif', 'PREC20061029.tif', 'PREC20061030.tif', 'PREC20061031.tif']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-39db724135c7> in <module>()
#      10     for m in range(1,13):
#      11         g[code+str(y)+str(m).zfill(2)] = []
# ---> 12         for name in sorted(glob.glob(path+code+'*.tif')):
#      13             rast = os.path.basename(name)
#      14             if rast[0:4] == code and int(rast[4:8]) == y and int(rast[8:10]) == m:
#
# KeyboardInterrupt:

# %%
sr = arcpy.SpatialReference(4326) #Spatial Projection WGS84

# Set output coordinate system
outCS = arcpy.SpatialReference('NAD 1983 UTM Zone 12N')  #NAD83 Zone 12 Code is 26912

# Set local variables
inMaskData = "H:/GIS/SNODAS/SNODAS.gdb/UT_HUC_area"

# from Table 4 of http://nsidc.org/data/docs/noaa/g02158_snodas_snow_cover_model/
prodcodelong = {1025: 'Precipitation', 1034: 'Snow water equivalent', 1036: 'Snow depth', 
            1038: 'Snow pack average temperature', 1039: 'Blowing snow sublimation',
            1044: 'Snow melt', 1050: 'Snow pack sublimation'}
prodcode = {1025: 'PREC', 1034: 'SWEQ', 1036: 'SNOD', 1038: 'SPAT', 1039: 'BSSB', 1044: 'SNML', 1050: 'SPSB'}

# iterate through data files creating rasters and defining projections
for dtfile in glob.glob("H:/GIS/SNODAS/SNODASUNZIPPED/SNODASUNGZ/*.dat"):
    indata = arcpy.Raster(dtfile)
    arcpy.DefineProjection_management(indata, sr)
    typAbb = prodcode[int(os.path.basename(dtfile)[8:12])]
    
    # Determine the new output feature class path and name = productcode + YYYYMMDD and save to a geodatabase
    outrast = "H:/GIS/SNODAS/SNODAS.gdb/" + typAbb + dtfile[-20:-11] #os.path.join(outWorkspace, rast)
    
    # Print name to veryfy save
    print(typAbb + dtfile[-20:-11])
    
    # Project Raster to UTM Zone 12
    arcpy.ProjectRaster_management(outExtractByMask, outrast, outCS, 'BILINEAR', '1000',\
                                   'WGS_1984_(ITRF00)_To_NAD_1983', '#', '#')

# %%
arcpy.env.overwriteOutput = True
path="H:/GIS/SNODAS/SNODASproj.gdb/"
arcpy.env.workspace = path
for name in arcpy.ListRasters():
# Out:
# [u'SWEQ200309MED',
#  u'SWEQ200310MED',
#  u'SWEQ200311MED',
#  u'SWEQ200312MED',
#  u'SWEQ200401MED',
#  u'SWEQ200402MED',
#  u'SWEQ200403MED',
#  u'SWEQ200404MED',
#  u'SWEQ200405MED',
#  u'SWEQ200406MED',
#  u'SWEQ200407MED',
#  u'SWEQ200408MED',
#  u'SWEQ200409MED',
#  u'SWEQ200410MED',
#  u'SWEQ200411MED',
#  u'SWEQ200412MED',
#  u'SWEQ200501MED',
#  u'SWEQ200502MED',
#  u'SWEQ200503MED',
#  u'SWEQ200504MED',
#  u'SWEQ200505MED',
#  u'SWEQ200506MED',
#  u'SWEQ200507MED',
#  u'SWEQ200508MED',
#  u'SWEQ200509MED',
#  u'SWEQ200510MED',
#  u'SWEQ200511MED',
#  u'SWEQ200512MED',
#  u'SWEQ200601MED',
#  u'SWEQ200602MED',
#  u'SWEQ200603MED',
#  u'SWEQ200604MED',
#  u'SWEQ200605MED',
#  u'SWEQ200606MED',
#  u'SWEQ200607MED',
#  u'SWEQ200608MED',
#  u'SWEQ200609MED',
#  u'SWEQ200610MED',
#  u'SWEQ200611MED',
#  u'SWEQ200612MED',
#  u'SWEQ200701MED',
#  u'SWEQ200702MED',
#  u'SWEQ200703MED',
#  u'SWEQ200704MED',
#  u'SWEQ200705MED',
#  u'SWEQ200706MED',
#  u'SWEQ200707MED',
#  u'SWEQ200708MED',
#  u'SWEQ200709MED',
#  u'SWEQ200710MED',
#  u'SWEQ200711MED',
#  u'SWEQ200712MED',
#  u'SWEQ200801MED',
#  u'SWEQ200802MED',
#  u'SWEQ200803MED',
#  u'SWEQ200804MED',
#  u'SWEQ200805MED',
#  u'SWEQ200806MED',
#  u'SWEQ200807MED',
#  u'SWEQ200808MED',
#  u'SWEQ200809MED',
#  u'SWEQ200810MED',
#  u'SWEQ200811MED',
#  u'SWEQ200812MED',
#  u'SWEQ200901MED',
#  u'SWEQ200902MED',
#  u'SWEQ200903MED',
#  u'SWEQ200904MED',
#  u'SWEQ200905MED',
#  u'SWEQ200906MED',
#  u'SWEQ200907MED',
#  u'SWEQ200908MED',
#  u'SWEQ200909MED',
#  u'SWEQ200910MED',
#  u'SWEQ200911MED',
#  u'SWEQ200912MED',
#  u'SWEQ201001MED',
#  u'SWEQ201002MED',
#  u'SWEQ201003MED',
#  u'SWEQ201004MED',
#  u'SWEQ201005MED',
#  u'SWEQ201006MED',
#  u'SWEQ201007MED',
#  u'SWEQ201008MED',
#  u'SWEQ201009MED',
#  u'SWEQ201010MED',
#  u'SWEQ201011MED',
#  u'SWEQ201012MED',
#  u'SWEQ201101MED',
#  u'SWEQ201102MED',
#  u'SWEQ201103MED',
#  u'SWEQ201104MED',
#  u'SWEQ201105MED',
#  u'SWEQ201106MED',
#  u'SWEQ201107MED',
#  u'SWEQ201108MED',
#  u'SWEQ201109MED',
#  u'SWEQ201110MED',
#  u'SWEQ201111MED',
#  u'SWEQ201112MED',
#  u'SWEQ201201MED',
#  u'SWEQ201202MED',
#  u'SWEQ201203MED',
#  u'SWEQ201204MED',
#  u'SWEQ201205MED',
#  u'SWEQ201206MED',
#  u'SWEQ201207MED',
#  u'SWEQ201208MED',
#  u'SWEQ201209MED',
#  u'SWEQ201210MED',
#  u'SWEQ201211MED',
#  u'SWEQ201212MED',
#  u'SWEQ201301MED',
#  u'SWEQ201302MED',
#  u'SWEQ201303MED',
#  u'SWEQ201304MED',
#  u'SWEQ201305MED',
#  u'SWEQ201306MED',
#  u'SWEQ201307MED',
#  u'SWEQ201308MED',
#  u'SWEQ201309MED',
#  u'SWEQ201310MED',
#  u'SWEQ201311MED',
#  u'SWEQ201312MED',
#  u'SWEQ201401MED',
#  u'SWEQ201402MED',
#  u'SWEQ201403MED',
#  u'SWEQ201404MED',
#  u'SWEQ201405MED',
#  u'SWEQ201406MED',
#  u'SWEQ201407MED',
#  u'SWEQ201408MED',
#  u'SWEQ201409MED',
#  u'SWEQ201410MED',
#  u'SWEQ201411MED',
#  u'SWEQ201412MED',
#  u'SWEQ201501MED',
#  u'SWEQ201502MED',
#  u'SWEQ201503MED',
#  u'SWEQ201504MED',
#  u'SWEQ201505MED',
#  u'SWEQ201506MED',
#  u'SWEQ201507MED',
#  u'SWEQ201508MED',
#  u'SWEQ201509MED',
#  u'SWEQ201510MED',
#  u'SWEQ201511MED',
#  u'SWEQ201512MED',
#  u'SWEQ201601MED',
#  u'SWEQ201602MED',
#  u'SWEQ201603MED',
#  u'SWEQ201604MED',
#  u'SWEQ201605MED',
#  u'SWEQ201606MED',
#  u'SWEQ201607MED',
#  u'SWEQ201608MED',
#  u'SWEQ201609MED',
#  u'RAIN200801SUM',
#  u'RAIN200802SUM',
#  u'RAIN200803SUM',
#  u'RAIN200804SUM',
#  u'RAIN200805SUM',
#  u'RAIN200806SUM',
#  u'RAIN200807SUM',
#  u'RAIN200808SUM',
#  u'RAIN200809SUM',
#  u'RAIN200810SUM',
#  u'RAIN200811SUM',
#  u'RAIN200812SUM',
#  u'RAIN200901SUM',
#  u'RAIN200902SUM',
#  u'RAIN200903SUM',
#  u'RAIN200904SUM',
#  u'RAIN200905SUM',
#  u'RAIN200906SUM',
#  u'RAIN200907SUM',
#  u'RAIN200908SUM',
#  u'RAIN200909SUM',
#  u'RAIN200910SUM',
#  u'RAIN200911SUM',
#  u'RAIN200912SUM',
#  u'RAIN201001SUM',
#  u'RAIN201002SUM',
#  u'RAIN201003SUM',
#  u'RAIN201004SUM',
#  u'RAIN201005SUM',
#  u'RAIN201006SUM',
#  u'RAIN201007SUM',
#  u'RAIN201008SUM',
#  u'RAIN201009SUM',
#  u'RAIN201010SUM',
#  u'RAIN201011SUM',
#  u'RAIN201012SUM',
#  u'RAIN201101SUM',
#  u'RAIN201102SUM',
#  u'RAIN201103SUM',
#  u'RAIN201104SUM',
#  u'RAIN201105SUM',
#  u'RAIN201106SUM',
#  u'RAIN201107SUM',
#  u'RAIN201108SUM',
#  u'RAIN201109SUM',
#  u'RAIN201110SUM',
#  u'RAIN201111SUM',
#  u'RAIN201112SUM',
#  u'RAIN201201SUM',
#  u'RAIN201202SUM',
#  u'RAIN201203SUM',
#  u'RAIN201204SUM',
#  u'RAIN201205SUM',
#  u'RAIN201206SUM',
#  u'RAIN201207SUM',
#  u'RAIN201208SUM',
#  u'RAIN201209SUM',
#  u'RAIN201210SUM',
#  u'RAIN201211SUM',
#  u'RAIN201212SUM',
#  u'RAIN201301SUM',
#  u'RAIN201302SUM',
#  u'RAIN201303SUM',
#  u'RAIN201304SUM',
#  u'RAIN201305SUM',
#  u'RAIN201306SUM',
#  u'RAIN201307SUM',
#  u'RAIN201308SUM',
#  u'RAIN201309SUM',
#  u'RAIN201310SUM',
#  u'RAIN201311SUM',
#  u'RAIN201312SUM',
#  u'RAIN201401SUM',
#  u'RAIN201402SUM',
#  u'RAIN201403SUM',
#  u'RAIN201404SUM',
#  u'RAIN201405SUM',
#  u'RAIN201406SUM',
#  u'RAIN201407SUM',
#  u'RAIN201408SUM',
#  u'RAIN201409SUM',
#  u'RAIN201410SUM',
#  u'RAIN201411SUM',
#  u'RAIN201412SUM',
#  u'RAIN201501SUM',
#  u'RAIN201502SUM',
#  u'RAIN201503SUM',
#  u'RAIN201504SUM',
#  u'RAIN201505SUM',
#  u'RAIN201506SUM',
#  u'RAIN201507SUM',
#  u'RAIN201508SUM',
#  u'RAIN201509SUM',
#  u'RAIN201510SUM',
#  u'RAIN201511SUM',
#  u'RAIN201512SUM',
#  u'RAIN201601SUM',
#  u'RAIN201602SUM',
#  u'RAIN201603SUM',
#  u'RAIN201604SUM',
#  u'RAIN201605SUM',
#  u'RAIN201606SUM',
#  u'RAIN201607SUM',
#  u'RAIN201608SUM',
#  u'RAIN201609SUM',
#  u'SNOW200801SUM',
#  u'SNOW200802SUM',
#  u'SNOW200803SUM',
#  u'SNOW200804SUM',
#  u'SNOW200805SUM',
#  u'SNOW200806SUM',
#  u'SNOW200807SUM',
#  u'SNOW200808SUM',
#  u'SNOW200809SUM',
#  u'SNOW200810SUM',
#  u'SNOW200811SUM',
#  u'SNOW200812SUM',
#  u'SNOW200901SUM',
#  u'SNOW200902SUM',
#  u'SNOW200903SUM',
#  u'SNOW200904SUM',
#  u'SNOW200905SUM',
#  u'SNOW200906SUM',
#  u'SNOW200907SUM',
#  u'SNOW200908SUM',
#  u'SNOW200909SUM',
#  u'SNOW200910SUM',
#  u'SNOW200911SUM',
#  u'SNOW200912SUM',
#  u'SNOW201001SUM',
#  u'SNOW201002SUM',
#  u'SNOW201003SUM',
#  u'SNOW201004SUM',
#  u'SNOW201005SUM',
#  u'SNOW201006SUM',
#  u'SNOW201007SUM',
#  u'SNOW201008SUM',
#  u'SNOW201009SUM',
#  u'SNOW201010SUM',
#  u'SNOW201011SUM',
#  u'SNOW201012SUM',
#  u'SNOW201101SUM',
#  u'SNOW201102SUM',
#  u'SNOW201103SUM',
#  u'SNOW201104SUM',
#  u'SNOW201105SUM',
#  u'SNOW201106SUM',
#  u'SNOW201107SUM',
#  u'SNOW201108SUM',
#  u'SNOW201109SUM',
#  u'SNOW201110SUM',
#  u'SNOW201111SUM',
#  u'SNOW201112SUM',
#  u'SNOW201201SUM',
#  u'SNOW201202SUM',
#  u'SNOW201203SUM',
#  u'SNOW201204SUM',
#  u'SNOW201205SUM',
#  u'SNOW201206SUM',
#  u'SNOW201207SUM',
#  u'SNOW201208SUM',
#  u'SNOW201209SUM',
#  u'SNOW201210SUM',
#  u'SNOW201211SUM',
#  u'SNOW201212SUM',
#  u'SNOW201301SUM',
#  u'SNOW201302SUM',
#  u'SNOW201303SUM',
#  u'SNOW201304SUM',
#  u'SNOW201305SUM',
#  u'SNOW201306SUM',
#  u'SNOW201307SUM',
#  u'SNOW201308SUM',
#  u'SNOW201309SUM',
#  u'SNOW201310SUM',
#  u'SNOW201311SUM',
#  u'SNOW201312SUM',
#  u'SNOW201401SUM',
#  u'SNOW201402SUM',
#  u'SNOW201403SUM',
#  u'SNOW201404SUM',
#  u'SNOW201405SUM',
#  u'SNOW201406SUM',
#  u'SNOW201407SUM',
#  u'SNOW201408SUM',
#  u'SNOW201409SUM',
#  u'SNOW201410SUM',
#  u'SNOW201411SUM',
#  u'SNOW201412SUM',
#  u'SNOW201501SUM',
#  u'SNOW201502SUM',
#  u'SNOW201503SUM',
#  u'SNOW201504SUM',
#  u'SNOW201505SUM',
#  u'SNOW201506SUM',
#  u'SNOW201507SUM',
#  u'SNOW201508SUM',
#  u'SNOW201509SUM',
#  u'SNOW201510SUM',
#  u'SNOW201511SUM',
#  u'SNOW201512SUM',
#  u'SNOW201601SUM',
#  u'SNOW201602SUM',
#  u'SNOW201603SUM',
#  u'SNOW201604SUM',
#  u'SNOW201605SUM',
#  u'SNOW201606SUM',
#  u'SNOW201607SUM',
#  u'SNOW201608SUM',
#  u'SNOW201609SUM',
#  u'RAIN200309SUM',
#  u'RAIN200310SUM',
#  u'RAIN200311SUM',
#  u'RAIN200312SUM',
#  u'RAIN200401SUM',
#  u'RAIN200402SUM',
#  u'RAIN200403SUM',
#  u'RAIN200404SUM',
#  u'RAIN200405SUM',
#  u'RAIN200406SUM',
#  u'RAIN200407SUM',
#  u'RAIN200408SUM',
#  u'RAIN200409SUM',
#  u'RAIN200410SUM',
#  u'RAIN200411SUM',
#  u'RAIN200412SUM',
#  u'RAIN200501SUM',
#  u'RAIN200502SUM',
#  u'RAIN200503SUM',
#  u'RAIN200504SUM',
#  u'RAIN200505SUM',
#  u'RAIN200506SUM',
#  u'RAIN200507SUM',
#  u'RAIN200508SUM',
#  u'RAIN200509SUM',
#  u'RAIN200510SUM',
#  u'RAIN200511SUM',
#  u'RAIN200512SUM',
#  u'RAIN200601SUM',
#  u'RAIN200602SUM',
#  u'RAIN200603SUM',
#  u'RAIN200604SUM',
#  u'RAIN200605SUM',
#  u'RAIN200606SUM',
#  u'RAIN200607SUM',
#  u'RAIN200608SUM',
#  u'RAIN200609SUM',
#  u'RAIN200610SUM',
#  u'RAIN200611SUM',
#  u'RAIN200612SUM',
#  u'RAIN200701SUM',
#  u'RAIN200702SUM',
#  u'RAIN200703SUM',
#  u'RAIN200704SUM',
#  u'RAIN200705SUM',
#  u'RAIN200706SUM',
#  u'RAIN200707SUM',
#  u'RAIN200708SUM',
#  u'RAIN200709SUM',
#  u'RAIN200710SUM',
#  u'RAIN200711SUM',
#  u'RAIN200712SUM',
#  u'SNOW200309SUM',
#  u'SNOW200310SUM',
#  u'SNOW200311SUM',
#  u'SNOW200312SUM',
#  u'SNOW200401SUM',
#  u'SNOW200402SUM',
#  u'SNOW200403SUM',
#  u'SNOW200404SUM',
#  u'SNOW200405SUM',
#  u'SNOW200406SUM',
#  u'SNOW200407SUM',
#  u'SNOW200408SUM',
#  u'SNOW200409SUM',
#  u'SNOW200410SUM',
#  u'SNOW200411SUM',
#  u'SNOW200412SUM',
#  u'SNOW200501SUM',
#  u'SNOW200502SUM',
#  u'SNOW200503SUM',
#  u'SNOW200504SUM',
#  u'SNOW200505SUM',
#  u'SNOW200506SUM',
#  u'SNOW200507SUM',
#  u'SNOW200508SUM',
#  u'SNOW200509SUM',
#  u'SNOW200510SUM',
#  u'SNOW200511SUM',
#  u'SNOW200512SUM',
#  u'SNOW200601SUM',
#  u'SNOW200602SUM',
#  u'SNOW200603SUM',
#  u'SNOW200604SUM',
#  u'SNOW200605SUM',
#  u'SNOW200606SUM',
#  u'SNOW200607SUM',
#  u'SNOW200608SUM',
#  u'SNOW200609SUM',
#  u'SNOW200610SUM',
#  u'SNOW200611SUM',
#  u'SNOW200612SUM',
#  u'SNOW200701SUM',
#  u'SNOW200702SUM',
#  u'SNOW200703SUM',
#  u'SNOW200704SUM',
#  u'SNOW200705SUM',
#  u'SNOW200706SUM',
#  u'SNOW200707SUM',
#  u'SNOW200708SUM',
#  u'SNOW200709SUM',
#  u'SNOW200710SUM',
#  u'SNOW200711SUM',
#  u'SNOW200712SUM',
#  u'SNML200309SUM',
#  u'SNML200310SUM',
#  u'SNML200311SUM',
#  u'SNML200312SUM',
#  u'SNML200401SUM',
#  u'SNML200402SUM',
#  u'SNML200403SUM',
#  u'SNML200404SUM',
#  u'SNML200405SUM',
#  u'SNML200406SUM',
#  u'SNML200407SUM',
#  u'SNML200408SUM',
#  u'SNML200409SUM',
#  u'SNML200410SUM',
#  u'SNML200411SUM',
#  u'SNML200412SUM',
#  u'SNML200501SUM',
#  u'SNML200502SUM',
#  u'SNML200503SUM',
#  u'SNML200504SUM',
#  u'SNML200505SUM',
#  u'SNML200506SUM',
#  u'SNML200507SUM',
#  u'SNML200508SUM',
#  u'SNML200509SUM',
#  u'SNML200510SUM',
#  u'SNML200511SUM',
#  u'SNML200512SUM',
#  u'SNML200601SUM',
#  u'SNML200602SUM',
#  u'SNML200603SUM',
#  u'SNML200604SUM',
#  u'SNML200605SUM',
#  u'SNML200606SUM',
#  u'SNML200607SUM',
#  u'SNML200608SUM',
#  u'SNML200609SUM',
#  u'SNML200610SUM',
#  u'SNML200611SUM',
#  u'SNML200612SUM',
#  u'SNML200701SUM',
#  u'SNML200702SUM',
#  u'SNML200703SUM',
#  u'SNML200704SUM',
#  u'SNML200705SUM',
#  u'SNML200706SUM',
#  u'SNML200707SUM',
#  u'SNML200708SUM',
#  u'SNML200709SUM',
#  u'SNML200710SUM',
#  u'SNML200711SUM',
#  u'SNML200712SUM',
#  u'SNML200801SUM',
#  u'SNML200802SUM',
#  u'SNML200803SUM',
#  u'SNML200804SUM',
#  u'SNML200805SUM',
#  u'SNML200806SUM',
#  u'SNML200807SUM',
#  u'SNML200808SUM',
#  u'SNML200809SUM',
#  u'SNML200810SUM',
#  u'SNML200811SUM',
#  u'SNML200812SUM',
#  u'SNML200901SUM',
#  u'SNML200902SUM',
#  u'SNML200903SUM',
#  u'SNML200904SUM',
#  u'SNML200905SUM',
#  u'SNML200906SUM',
#  u'SNML200907SUM',
#  u'SNML200908SUM',
#  u'SNML200909SUM']

# %%
monthRange = [1,12] 
yearRange = [2003,2016]

g = {}
path="H:/GIS/SNODAS/SNODASproj.gdb/"
arcpy.env.workspace = path
arcpy.env.overwriteOutput = True


for y in range(yearRange[0],yearRange[1]+1): #set years converted here
    for m in range(monthRange[0],monthRange[1]+1): #set months converted here
        my = str(y)+str(m).zfill(2)
        newdn = 'TPPT' + my
        try:
            calc = Plus('SNOW'+ my +'SUM', 'RAIN'+ my +'SUM')
            calc.save(newdn+'SUM')
            print(newdn)
        except(RuntimeError):
            pass
# Out:
# TPPT200309
# TPPT200310
# TPPT200311
# TPPT200312
# TPPT200401
# TPPT200402
# TPPT200403
# TPPT200404
# TPPT200405
# TPPT200406
# TPPT200407
# TPPT200408
# TPPT200409
# TPPT200410
# TPPT200411
# TPPT200412
# TPPT200501
# TPPT200502
# TPPT200503
# TPPT200504
# TPPT200505
# TPPT200506
# TPPT200507
# TPPT200508
# TPPT200509
# TPPT200510
# TPPT200511
# TPPT200512
# TPPT200601
# TPPT200602
# TPPT200603
# TPPT200604
# TPPT200605
# TPPT200606
# TPPT200607
# TPPT200608
# TPPT200609
# TPPT200610
# TPPT200611
# TPPT200612
# TPPT200701
# TPPT200702
# TPPT200703
# TPPT200704
# TPPT200705
# TPPT200706
# TPPT200707
# TPPT200708
# TPPT200709
# TPPT200710
# TPPT200711
# TPPT200712
# TPPT200801
# TPPT200802
# TPPT200803
# TPPT200804
# TPPT200805
# TPPT200806
# TPPT200807
# TPPT200808
# TPPT200809
# TPPT200810
# TPPT200811
# TPPT200812
# TPPT200901
# TPPT200902
# TPPT200903
# TPPT200904
# TPPT200905
# TPPT200906
# TPPT200907
# TPPT200908
# TPPT200909
# TPPT200910
# TPPT200911
# TPPT200912
# TPPT201001
# TPPT201002
# TPPT201003
# TPPT201004
# TPPT201005
# TPPT201006
# TPPT201007
# TPPT201008
# TPPT201009
# TPPT201010
# TPPT201011
# TPPT201012
# TPPT201101
# TPPT201102
# TPPT201103
# TPPT201104
# TPPT201105
# TPPT201106
# TPPT201107
# TPPT201108
# TPPT201109
# TPPT201110
# TPPT201111
# TPPT201112
# TPPT201201
# TPPT201202
# TPPT201203
# TPPT201204
# TPPT201205
# TPPT201206
# TPPT201207
# TPPT201208
# TPPT201209
# TPPT201210
# TPPT201211
# TPPT201212
# TPPT201301
# TPPT201302
# TPPT201303
# TPPT201304
# TPPT201305
# TPPT201306
# TPPT201307
# TPPT201308
# TPPT201309
# TPPT201310
# TPPT201311
# TPPT201312
# TPPT201401
# TPPT201402
# TPPT201403
# TPPT201404
# TPPT201405
# TPPT201406
# TPPT201407
# TPPT201408
# TPPT201409
# TPPT201410
# TPPT201411
# TPPT201412
# TPPT201501
# TPPT201502
# TPPT201503
# TPPT201504
# TPPT201505
# TPPT201506
# TPPT201507
# TPPT201508
# TPPT201509
# TPPT201510
# TPPT201511
# TPPT201512
# TPPT201601
# TPPT201602
# TPPT201603
# TPPT201604
# TPPT201605
# TPPT201606
# TPPT201607
# TPPT201608
# TPPT201609

# %%
from arcpy.sa import *

monthRange = [1,12] 
yearRange = [2005,2005]

path = "H:/GIS/Calc.gdb/"
path1 = "H:/GIS/SNODAS/SNODASproj.gdb/"
path2 = "H:/GIS/MODIS/MODOUT.gdb/"
arcpy.env.workspace = path
arcpy.env.overwriteOutput = True
area = 'H:/GIS/NHD_UT_Proj.gdb/UT_HUC_area'
arcpy.env.mask = area

for y in range(yearRange[0],yearRange[1]+1): #set years converted here
    for m in range(monthRange[0],monthRange[1]+1): #set months converted here
        my = str(y)+str(m).zfill(2)
        newdn = 'AVLW' + my
        rain = (path1 + 'RAIN'+ my +'SUM')
        snowMelt = (path1 + 'SNML'+ my +'SUM')
        actEvap = (path2 + 'AET'+ my)
        
        avail = (Con(IsNull(rain),0, rain)) + (Con(IsNull(snowMelt),0, snowMelt)) - (Con(IsNull(actEvap),0, actEvap))
        avail = (available < 0, 0, available)
        available.save(newdn)
        print(newdn)
